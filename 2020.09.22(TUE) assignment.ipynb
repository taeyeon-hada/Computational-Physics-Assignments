# %% [markdown]
# ## Boston House Price

# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression, Ridge, Lasso
import matplotlib.pyplot as plt
import numpy as np

# %%
boston = load_boston()

# %%
X=boston.data
y=boston.target

# %%
plt.plot(X,y,'.')
# Out:
# [<matplotlib.lines.Line2D at 0x2778ba9b8c8>,
#  <matplotlib.lines.Line2D at 0x2778baa5588>,
#  <matplotlib.lines.Line2D at 0x2778baa5548>,
#  <matplotlib.lines.Line2D at 0x2778baa5788>,
#  <matplotlib.lines.Line2D at 0x2778baa5cc8>,
#  <matplotlib.lines.Line2D at 0x2778baa5f88>,
#  <matplotlib.lines.Line2D at 0x2778baa5e48>,
#  <matplotlib.lines.Line2D at 0x2778baaa148>,
#  <matplotlib.lines.Line2D at 0x2778baa5988>,
#  <matplotlib.lines.Line2D at 0x2778baa5bc8>,
#  <matplotlib.lines.Line2D at 0x2778ba8ca48>,
#  <matplotlib.lines.Line2D at 0x2778baaaac8>,
#  <matplotlib.lines.Line2D at 0x2778baaad08>]

# %%
reg=LinearRegression()
lasso_reg=Lasso(alpha=10)

reg.fit(X,y)
lasso_reg.fit(X,y)
# Out:
# Lasso(alpha=10, copy_X=True, fit_intercept=True, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
#       tol=0.0001, warm_start=False)

# %%
reg.coef_ , reg.intercept_
# Out:
# (array([-1.08011358e-01,  4.64204584e-02,  2.05586264e-02,  2.68673382e+00,
#         -1.77666112e+01,  3.80986521e+00,  6.92224640e-04, -1.47556685e+00,
#          3.06049479e-01, -1.23345939e-02, -9.52747232e-01,  9.31168327e-03,
#         -5.24758378e-01]),
#  36.459488385089855)

# %%
reg.predict(X)
# Out:
# array([30.00384338, 25.02556238, 30.56759672, 28.60703649, 27.94352423,
#        25.25628446, 23.00180827, 19.53598843, 11.52363685, 18.92026211,
#        18.99949651, 21.58679568, 20.90652153, 19.55290281, 19.28348205,
#        19.29748321, 20.52750979, 16.91140135, 16.17801106, 18.40613603,
#        12.52385753, 17.67103669, 15.83288129, 13.80628535, 15.67833832,
#        13.38668561, 15.46397655, 14.70847428, 19.54737285, 20.8764282 ,
#        11.45511759, 18.05923295,  8.81105736, 14.28275814, 13.70675891,
#        23.81463526, 22.34193708, 23.10891142, 22.91502612, 31.35762569,
#        34.21510225, 28.02056414, 25.20386628, 24.60979273, 22.94149176,
#        22.09669817, 20.42320032, 18.03655088,  9.10655377, 17.20607751,
#        21.28152535, 23.97222285, 27.6558508 , 24.04901809, 15.3618477 ,
#        31.15264947, 24.85686978, 33.10919806, 21.77537987, 21.08493555,
#        17.8725804 , 18.51110208, 23.98742856, 22.55408869, 23.37308644,
#        30.36148358, 25.53056512, 21.11338564, 17.42153786, 20.78483633,
#        25.20148859, 21.7426577 , 24.55744957, 24.04295712, 25.50499716,
#        23.9669302 , 22.94545403, 23.35699818, 21.26198266, 22.42817373,
#        28.40576968, 26.99486086, 26.03576297, 25.05873482, 24.78456674,
#        27.79049195, 22.16853423, 25.89276415, 30.67461827, 30.83110623,
#        22.22225914, 19.65591961, 21.32536104, 11.85583717,  8.22386687,
#         3.66399672, 13.75908538, 15.93118545, 20.62662054, 20.61249414,
#        16.88541964, 14.01320787, 19.10854144, 21.29805174, 18.45498841,
#        20.46870847, 23.53334055, 22.37571892, 27.6274261 , 26.12796681,
#        22.34421229])

# %%
plt.plot(X,y,'o')
plt.plot(X,reg.predict(X))
# Out:
# [<matplotlib.lines.Line2D at 0x2778bb0c348>,
#  <matplotlib.lines.Line2D at 0x2778bb57608>,
#  <matplotlib.lines.Line2D at 0x2778bb577c8>,
#  <matplotlib.lines.Line2D at 0x2778bb57988>,
#  <matplotlib.lines.Line2D at 0x2778bb57b48>,
#  <matplotlib.lines.Line2D at 0x2778bb57d48>,
#  <matplotlib.lines.Line2D at 0x2778bb57f08>,
#  <matplotlib.lines.Line2D at 0x2778bb5a108>,
#  <matplotlib.lines.Line2D at 0x2778bb5a2c8>,
#  <matplotlib.lines.Line2D at 0x2778bb57d08>,
#  <matplotlib.lines.Line2D at 0x2778bb5a608>,
#  <matplotlib.lines.Line2D at 0x2778bb5a7c8>,
#  <matplotlib.lines.Line2D at 0x2778bb5aa08>]

# %%
for a, b in zip(boston.feature_names, reg.coef_):
    print("%s: %f" %(a,b))
# Out:
# CRIM: -0.108011
# ZN: 0.046420
# INDUS: 0.020559
# CHAS: 2.686734
# NOX: -17.766611
# RM: 3.809865
# AGE: 0.000692
# DIS: -1.475567
# RAD: 0.306049
# TAX: -0.012335
# PTRATIO: -0.952747
# B: 0.009312
# LSTAT: -0.524758

# %% [markdown]
# ## Diabetes

# %%
from sklearn.datasets import load_diabetes

# %%
dia = load_diabetes()

# %%
X=dia.data
y=dia.data

# %%
plt.plot(X,y,'.')
# Out:
# [<matplotlib.lines.Line2D at 0x2778bbeff88>,
#  <matplotlib.lines.Line2D at 0x2778bbfb188>,
#  <matplotlib.lines.Line2D at 0x2778bbfb148>,
#  <matplotlib.lines.Line2D at 0x2778bbfb388>,
#  <matplotlib.lines.Line2D at 0x2778bbfb848>,
#  <matplotlib.lines.Line2D at 0x2778bbfba88>,
#  <matplotlib.lines.Line2D at 0x2778bbfb9c8>,
#  <matplotlib.lines.Line2D at 0x2778bbfbc08>,
#  <matplotlib.lines.Line2D at 0x2778bbfb588>,
#  <matplotlib.lines.Line2D at 0x2778bbfb788>]

# %%
reg=LinearRegression()
lasso_reg=Lasso(alpha=10)

reg.fit(X,y)
lasso_reg.fit(X,y)
# Out:
# Lasso(alpha=10, copy_X=True, fit_intercept=True, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
#       tol=0.0001, warm_start=False)

# %%
reg.coef_ , reg.intercept_
# Out:
# (array([[ 1.00000000e+00,  4.19667218e-16, -3.13978994e-16,
#          -4.37735011e-16,  4.40049393e-17,  7.37494270e-17,
#          -4.06341806e-16,  3.46251867e-16, -2.16447908e-16,
#          -3.01977929e-16],
#         [ 5.80728984e-16,  1.00000000e+00, -5.76869238e-16,
#          -3.11787744e-16, -1.00075350e-15,  5.72640409e-16,
#           2.29248358e-18, -1.60457622e-16,  1.00480716e-16,
#          -6.06805244e-17],
#         [-3.75415602e-16, -9.82862673e-16,  1.00000000e+00,
#           1.48887525e-16,  5.72862274e-16, -4.56114360e-16,
#          -6.23070221e-17, -1.97508952e-16,  5.08765689e-16,
#          -6.60232925e-17],
#         [ 1.05285330e-16,  7.69714081e-18,  1.76884714e-16,
#           1.00000000e+00,  3.44662745e-16, -5.65295070e-16,
#          -1.93785804e-16,  1.10414387e-16, -2.46088561e-16,
#          -3.67342771e-16],
#         [-8.40448356e-17, -4.34819054e-17, -7.86364234e-17,
#           8.36035995e-17,  1.00000000e+00,  2.54285456e-16,
#          -1.33732288e-16, -4.91030496e-17,  1.54928736e-16,
#          -4.96591695e-17],
#         [-6.49194852e-17,  6.56575059e-17, -4.57423073e-16,
#          -6.66743991e-17,  2.26006749e-16,  1.00000000e+00,
#          -2.55312902e-16, -3.37032880e-16,  2.87020404e-16,
#           1.36592350e-16],
#         [-3.45335629e-17, -6.07289200e-16, -7.85519943e-17,
#          -2.82282776e-16, -8.21537460e-16,  6.97803418e-16,
#           1.00000000e+00, -5.33752092e-16,  3.08214631e-16,
#          -8.58201965e-17],
#         [-4.75874464e-17, -2.30733858e-16, -5.54621929e-17,
#           4.18256267e-16, -3.17905088e-16,  5.69278713e-16,
#           6.42289046e-16,  1.00000000e+00,  1.93722725e-16,
#           1.41643397e-16],
#         [-8.52446238e-17,  3.33741218e-16,  4.29319069e-16,
#           9.64486111e-17,  1.53688082e-16,  3.77645642e-17,
#           2.18389421e-16,  3.12452596e-16,  1.00000000e+00,
#           1.30412990e-16],
#         [-1.20493540e-17,  3.53878516e-16,  2.23884421e-16,
#          -2.47203200e-16,  1.57740712e-16,  9.13262388e-17,
#           2.97052906e-16,  4.77030502e-17, -4.42829349e-17,
#           1.00000000e+00]]),
#  array([-6.40949485e-31, -3.20474743e-31,  6.90253292e-31, -9.86076132e-32,
#         -1.35585468e-31, -1.72563323e-31,  0.00000000e+00,  9.86076132e-32,
#          4.93038066e-32,  2.46519033e-31]))

# %%
reg.predict(X)
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
plt.plot(X,y,'o')
plt.plot(X,reg.predict(X))
# Out:
# [<matplotlib.lines.Line2D at 0x2778cc231c8>,
#  <matplotlib.lines.Line2D at 0x2778cc6bcc8>,
#  <matplotlib.lines.Line2D at 0x2778cc6be88>,
#  <matplotlib.lines.Line2D at 0x2778cc72088>,
#  <matplotlib.lines.Line2D at 0x2778cc72248>,
#  <matplotlib.lines.Line2D at 0x2778cc72448>,
#  <matplotlib.lines.Line2D at 0x2778cc72608>,
#  <matplotlib.lines.Line2D at 0x2778cc727c8>,
#  <matplotlib.lines.Line2D at 0x2778cc72988>,
#  <matplotlib.lines.Line2D at 0x2778cc72408>]
